# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from astropy.io import fits

# %%
path='/Users/connor_auge/Research/Disertation/morphology/visual/COSMOS/cosmos_cutouts_sample_published/'

# %%
path='/Users/connor_auge/Research/Disertation/morphology/cosmos_jwst/jwst_f150_cutouts_sample/'

with fits.open(path+'685399.fits') as hdul:

# %%
with fits.open(path+'lid_0548220.fits') as hdul:
    data = hdul[0].data

# %%
data[data < 1] = 1 

fig = plt.figure(figsize=(8,8))
# im = plt.imshow(data,norm=LogNorm(vmin=np.min(data),vmax=np.max(data)))
# im = plt.imshow(data,norm=LogNorm(vmin=0.01,vmax=np.max(data)),cmap='gray')
im = plt.imshow(data,norm=LogNorm(vmin=1,vmax=np.max(data)),cmap='gray')

# fig.colorbar(im)
plt.gca().invert_yaxis()
